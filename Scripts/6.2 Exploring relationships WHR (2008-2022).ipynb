# %% [markdown]
# # This script contains the following points:
#
#
# ### 01. Import libraries
# ### 02. Import data
# ### 03. Exploring Relationships
#      Correlations
#      Scatterplots
#      Pair Plots
#      Categorical Plots
# ### 04. Responses to some questions
# ### 05. New question
# ### 06. Hypotheses

# %% [markdown]
# # 01. Import libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %%
# This option ensures charts created are displayed in the notebook without the need to "call" them specifically

# %matplotlib inline

# %% [markdown]
# # 02. Import data

# %%
# Set path

path = r'C:\Users\nang6\OneDrive\Bureau\Data Analytics\Data Immersion\Achievement 6'

# %%
# Import data set

df = pd.read_csv(os.path.join(path, 'Open Data Source', 'Cleaned Data', 'WHR (2008-2022)_checked.csv'), index_col = False)

# %%
# Check size

df.shape
# Out:
# (2199, 13)

# %%
# Check column names

df.columns
# Out:
# Index(['Unnamed: 0', 'Country', 'Region', 'Year', 'Happiness Score',
#        'GDP per Capita', 'Social Support', 'Life Expectancy', 'Freedom',
#        'Charity', 'Corruption Perception', 'Positive Emotions',
#        'Negative Emotions'],
#       dtype='object')

# %%
# Drop Unnamed column

df = df.drop(columns = ['Unnamed: 0'])

# %%
# Recheck column names

df.columns
# Out:
# Index(['Country', 'Region', 'Year', 'Happiness Score', 'GDP per Capita',
#        'Social Support', 'Life Expectancy', 'Freedom', 'Charity',
#        'Corruption Perception', 'Positive Emotions', 'Negative Emotions'],
#       dtype='object')

# %% [markdown]
# ## 3. Exploring Relationships

# %% [markdown]
# ### Correlations:

# %% [markdown]
# #### Create a correlation heatmap

# %%
# Create a subset excluding the "Country", "Region" and "Year" columns

sub = df[['Happiness Score', 'GDP per Capita','Social Support', 'Life Expectancy', 'Freedom', 'Charity', 'Corruption Perception', 'Positive Emotions', 'Negative Emotions']]

# %%
sub
# Out:
#       Happiness Score  GDP per Capita  Social Support  Life Expectancy  \
# 0               3.724           7.350           0.451           50.500
# 1               4.402           7.509           0.552           50.800
# 2               4.758           7.614           0.539           51.100
# 3               3.832           7.581           0.521           51.400
# 4               3.783           7.661           0.521           51.700
# ...               ...             ...             ...              ...
# 2194            3.616           7.783           0.775           52.625
# 2195            2.694           7.698           0.759           53.100
# 2196            3.160           7.596           0.717           53.575
# 2197            3.155           7.657           0.685           54.050
# 2198            3.296           7.670           0.666           54.525
#
#       Freedom  Charity  Corruption Perception  Positive Emotions  \
# ...

# %%
# Create a subplot with matplotlib

f,ax = plt.subplots(figsize=(10,10))

# Create the correlation heatmap in seaborn by applying a heatmap onto the correlation matrix and the subplots defined above.

corr = sns.heatmap(sub.corr(), annot = True, ax = ax) # The 'annot' argument allows the plot to 
#place the correlation coefficients onto the heatmap.

# %% [markdown]
# #### Legend:
#     Purple equates to 0, or no relationship between the variables
#     Dark purple and black equate to negative correlations
#     Orange and light orange equate to positive correlations

# %% [markdown]
# #### Observation:
#
# The important variable here is Happiness Score variable as it measures the country's overall happiness and well-being.
#
# There are strong and positive correlations between Happiness Score and:
#
# - GDP per Capita (0.78)
# - Social Support (0.72)
# - Life Expectancy (0.71)
#
# We can also see a strong and positive relationship:
#
# - Between GDP per Capita and Life Expectancy (0.82)
#
# This correlation may highlights the importance of economic development in promoting improved health outcomes, and suggests that investments in economic growth and development may have positive spillover effects on population health.
#
# There are medium-to-strong positive correlations between Happiness Score and:
#
# - Fredom to make life choices (0.53)
# - Positive Emotions (0.52)
#
# On the other hand we can also see a moderate negative relationship between Happiness Score and:
#
# - Corruption Perception (-0.43)
# - Negative Emotions (-0.34)
#
# This may suggests that as Corruption Perception and Negative Emotions (i.e. feelings of sadness, anger, worry, and stress) increase within a country, the Happiness Score tends to decrease, indicating lower levels of happiness and well-being among its citizens and vice-versa.

# %% [markdown]
# ### Scatterplots:

# %%
# Create a scatterplot for the "Happiness Score" and "GDP per Capita" columns in seaborn

sns.lmplot(x = 'Happiness Score', y = 'GDP per Capita', data = df)

# %%
# Create a scatterplot for the "Happiness Score" and "Social Support" columns in seaborn

sns.lmplot(x = 'Happiness Score', y = 'Social Support', data = df)

# %%
# Create a scatterplot for the "Happiness Score" and "Life Expectancy" columns in seaborn

sns.lmplot(x = 'Happiness Score', y = 'Life Expectancy', data = df)

# %%
# Create a scatterplot for the "GDP per Capita" and "Life Expectancy" columns in seaborn

sns.lmplot(x = 'GDP per Capita', y = 'Life Expectancy', data = df)

# %% [markdown]
# #### Observation:
#
# All scatterplots show:
#
# - Strong and positive relationships between variables listed above
# - Linear trends
# - Some outliers

# %% [markdown]
# ### Pair Plots

# %%
# Create a pair plot of the entire data set

g = sns.pairplot(sub)

# %% [markdown]
# #### Observation:
#
# - The distribution of the Happiness Score variable is relatively normally distributed.
#
# - The distribution of other variables, such as GDP per Capita, Social Support, Life Expectancy and Corruption Perception, is relatively  left skewed.
#
# - Variables that may be worth exploring further include Corruption Perception and Negative Emotions, which have been shown to have a negative impact on happiness and well-being.
#
# - Additionally, the relationship between GDP per Capita and Life Expectancy, may also be of interest.

# %% [markdown]
# ### Categorical Plots:

# %% [markdown]
# ##### Creating a categorical variable that splits the "Happiness Score" column into categories

# %%
# Use a histogram to visualize the distribution of the variables. 
# This way, we can determine sensible categories for the ranges. 
# We don't want to end up with too few observations in any one of the categories.
# The argument "kde" add a line that encompasses the distribution

sns.histplot(df['Happiness Score'], bins = 20, kde = True)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Count'>

# %%
df.loc[df['Happiness Score'] < 4, 'Happiness Score Category'] = 'Low score'

# %%
df.loc[(df['Happiness Score'] >= 4) & (df['Happiness Score'] < 7), 'Happiness Score Category'] = 'Middle score'

# %%
df.loc[df['Happiness Score'] >= 7, 'Happiness Score Category'] = 'High score'

# %%
df['Happiness Score Category'].value_counts(dropna = False)
# Out:
# Middle score    1744
# High score       251
# Low score        204
# Name: Happiness Score Category, dtype: int64

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Year', 'Happiness Score', 'GDP per Capita',
#        'Social Support', 'Life Expectancy', 'Freedom', 'Charity',
#        'Corruption Perception', 'Positive Emotions', 'Negative Emotions',
#        'Happiness Score Category'],
#       dtype='object')

# %%
# Create a categorical plot in seaborn using the Happiness Score categories created above

sns.set(style='ticks')
g = sns.catplot(x='Happiness Score', y='GDP per Capita', hue='Happiness Score Category', data=df)

# %%
# Export

g.savefig('catplot.png')

# %% [markdown]
# #### Observation:
#
# With the categorical plot, we can see that there is a clear trend where higher "GDP per Capita" values are associated with higher "Happiness Score" values across all categories.

# %% [markdown]
# # 04. Responses to some questions

# %% [markdown]
# #### Is there a relationship between a country's GDP per capita and its level of happiness?
#
# - Yes, based on the categorical plot, we can see a positive relationship between these two variables.

# %% [markdown]
# #### How does Social Support impact a country's happiness score?
#
# - Based on the correlation heatmap coefficient of 0.72 for these two variables, we can say that the Social Support has a positive impact on the country's hapiness score.

# %% [markdown]
# #### Is there a relationship between life expectancy and happiness score?
#
# - Yes, based on the scaterplot vizualisation, we can see a positive relationship between these two variables.

# %% [markdown]
# #### Does a country's level of freedom impact its happiness score?
#
# - There is a medium-to-strong positive correlation between Happiness Score and Fredom(0.53) but it is not the strongest relationship, therefore we can say that it may slightly impact.

# %% [markdown]
# #### Is there a correlation between a country's charity and its happiness score?
#
# - Based on the correlation heatmap coefficient of 0.18 for these two variables, we can say that there is no correlation between a country's charity and its happiness score.

# %% [markdown]
# #### How does a country's perceived level of corruption affect its happiness score?
#
# - When perception of corruption increases within a country, the Happiness Score score tends to decrease, indicating lower levels of happiness and well-being among its citizens.

# %% [markdown]
# # 05. New question

# %% [markdown]
# #### Is there a causal relationship between higher levels of economic development, as measured by GDP per capita, and longer and healthier lives, as measured by Life Expectancy?
#
# - There is a strong and positive relationship between a country's economic development (as measured by GDP per Capita) and the health of its citizens (as measured by life expectancy) as shown with the heatmap.
#
# - This relationship is consistent with the idea that a higher standard of living is associated with better health outcomes. In countries where people have higher incomes and greater access to healthcare, they may be more likely to live longer and healthier lives.

# %% [markdown]
# # 06. Hypotheses

# %% [markdown]
# - Hypothesis 1: Economic Development, Social Support and Life Expectancy are positively associated with overall happiness and well-being.
#
# This hypothesis is based on the strong correlation between these variables.
#
# - Hypothesis 2: Countries with lower levels of corruption have higher levels of happiness and well-being.
#
# This hypothesis is based on the negative correlation between perception of corruption and the Happiness Score variable.
#
# - Hypothesis 3: Negative Emotions is negatively associated with overall happiness and well-being.
#
# This hypothesis is based on the negative correlation between Negative Emotions and the Happiness Score variable observed.
#
# - Hypotesis 4: Higher levels of economic development, as measured by GDP per capita, are associated with longer and healthier lives, as measured by Life Expectancy.
#
# This hypothesis is based on the strong and positive relationship between GDP per Capita and Life Expectancy variables.

# %%
# Export

df.to_csv(os.path.join(path, 'Open Data Source','Cleaned Data', 'WHR (2008-2022)_checked_2.csv'))
